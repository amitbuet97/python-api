# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from pprint import pprint
# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Start building URL


url = "http://api.openweathermap.org/data/2.5/weather?"
#city = "Bujumbura"
units = "imperial"

query_url = f"{url}appid={api_key}&q={city}&units={units}"


# Create empty List to store the values

lat=[]
lon = []
maxtemp = []
cloud = []
windspeed = []
humidity = []
citynew = []
date = []
country = []
value =1 

#Running loop for all cities

for city in cities:
    
    # Jso-ified the API response
    
    query_url = f"{url}appid={api_key}&q={city}&units={units}"
    response = requests.get(query_url).json()
    
    #Error checking for cities not found
    
    if response["cod"] == "404":
        print("City not found, skipping...")
        
    
    #building list for found cities.
    
    else:
        
        
        
        
        print(f"Processing Record {value} of Set 1 | {city}.")
        
        #Append the blanc list
        
        lat.append(response['coord']['lat'])
        
        lon.append(response['coord']['lon'])
        
        maxtemp.append(response['main']['temp_max'])
        
        cloud.append(response['clouds']['all'])
        
        windspeed.append(response['wind']['speed'])
        
        humidity.append(response['main']['humidity'])
        
        citynew.append(response['name'])
        
        date.append(response['dt'])
        
        country.append(response['sys']['country']) 
        
        value = value+1
# Out:
# Processing Record 1 of Set 1 | butaritari.
# Processing Record 2 of Set 1 | rikitea.
# Processing Record 3 of Set 1 | pangnirtung.
# Processing Record 4 of Set 1 | choix.
# Processing Record 5 of Set 1 | tuatapere.
# Processing Record 6 of Set 1 | copiapo.
# Processing Record 7 of Set 1 | namatanai.
# Processing Record 8 of Set 1 | tuktoyaktuk.
# Processing Record 9 of Set 1 | la palma.
# Processing Record 10 of Set 1 | nanortalik.
# Processing Record 11 of Set 1 | cairns.
# Processing Record 12 of Set 1 | busselton.
# Processing Record 13 of Set 1 | ewa beach.
# Processing Record 14 of Set 1 | ushuaia.
# City not found, skipping...
# Processing Record 15 of Set 1 | port elizabeth.
# Processing Record 16 of Set 1 | jamestown.
# Processing Record 17 of Set 1 | waipawa.
# Processing Record 18 of Set 1 | etchoropo.
# Processing Record 19 of Set 1 | kaitangata.
# Processing Record 20 of Set 1 | yakeshi.
# Processing Record 21 of Set 1 | fortuna.
# Processing Record 22 of Set 1 | bonito.
# Processing Record 23 of Set 1 | kavieng.
# Processing Record 24 of Set 1 | kodiak.
# City not found, skipping...
# Processing Record 25 of Set 1 | atuona.
# Processing Record 26 of Set 1 | hamilton.
# City not found, skipping...
# Processing Record 27 of Set 1 | chapais.
# Processing Record 28 of Set 1 | marrakesh.
# City not found, skipping...
# Processing Record 29 of Set 1 | goure.
# City not found, skipping...
# Processing Record 30 of Set 1 | mataura.
# Processing Record 31 of Set 1 | sur.
# Processing Record 32 of Set 1 | bol.
# Processing Record 33 of Set 1 | puerto ayora.
# Processing Record 34 of Set 1 | nyrob.
# Processing Record 35 of Set 1 | hasaki.
# Processing Record 36 of Set 1 | norman wells.
# Processing Record 37 of Set 1 | guhagar.
# Processing Record 38 of Set 1 | punta arenas.
# Processing Record 39 of Set 1 | hermanus.
# Processing Record 40 of Set 1 | vaini.
# City not found, skipping...
# Processing Record 41 of Set 1 | bredasdorp.
# Processing Record 42 of Set 1 | mar del plata.
# Processing Record 43 of Set 1 | chongwe.
# Processing Record 44 of Set 1 | jilib.
# Processing Record 45 of Set 1 | roma.
# Processing Record 46 of Set 1 | chokurdakh.
# City not found, skipping...
# City not found, skipping...
# Processing Record 47 of Set 1 | nouadhibou.
# Processing Record 48 of Set 1 | san vicente.
# Processing Record 49 of Set 1 | tahoua.
# City not found, skipping...
# Processing Record 50 of Set 1 | fairbanks.
# Processing Record 51 of Set 1 | hobart.
# Processing Record 52 of Set 1 | carnarvon.
# Processing Record 53 of Set 1 | pevek.
# Processing Record 54 of Set 1 | zhigansk.
# Processing Record 55 of Set 1 | inirida.
# Processing Record 56 of Set 1 | katsuura.
# City not found, skipping...
# City not found, skipping...
# Processing Record 57 of Set 1 | saldanha.
# Processing Record 58 of Set 1 | bluff.
# Processing Record 59 of Set 1 | adrar.
# Processing Record 60 of Set 1 | yellowknife.
# Processing Record 61 of Set 1 | sobolevo.
# Processing Record 62 of Set 1 | manggar.
# Processing Record 63 of Set 1 | dikson.
# Processing Record 64 of Set 1 | atambua.
# Processing Record 65 of Set 1 | east london.
# Processing Record 66 of Set 1 | bria.
# Processing Record 67 of Set 1 | pisco.
# Processing Record 68 of Set 1 | noumea.
# Processing Record 69 of Set 1 | saint george.
# Processing Record 70 of Set 1 | vryheid.
# City not found, skipping...
# Processing Record 71 of Set 1 | barrow.
# Processing Record 72 of Set 1 | mezhdurechensk.
# Processing Record 73 of Set 1 | thompson.
# Processing Record 74 of Set 1 | vestmannaeyjar.
# City not found, skipping...
# Processing Record 75 of Set 1 | comodoro rivadavia.
# Processing Record 76 of Set 1 | gazanjyk.
# Processing Record 77 of Set 1 | ibotirama.
# City not found, skipping...
# Processing Record 78 of Set 1 | rio rancho.
# Processing Record 79 of Set 1 | zhangjiakou.
# Processing Record 80 of Set 1 | albany.
# Processing Record 81 of Set 1 | castro.
# Processing Record 82 of Set 1 | dingle.
# Processing Record 83 of Set 1 | kapit.
# Processing Record 84 of Set 1 | port-gentil.
# Processing Record 85 of Set 1 | lebu.
# Processing Record 86 of Set 1 | calatrava.
# Processing Record 87 of Set 1 | souillac.
# Processing Record 88 of Set 1 | sovetskiy.
# Processing Record 89 of Set 1 | yar-sale.
# Processing Record 90 of Set 1 | konevo.
# Processing Record 91 of Set 1 | bethel.
# Processing Record 92 of Set 1 | nikolskoye.
# Processing Record 93 of Set 1 | avarua.
# City not found, skipping...
# Processing Record 94 of Set 1 | sao lourenco do sul.
# Processing Record 95 of Set 1 | kuching.
# Processing Record 96 of Set 1 | sumbe.
# Processing Record 97 of Set 1 | brae.
# Processing Record 98 of Set 1 | nikolayevsk-na-amure.
# Processing Record 99 of Set 1 | guerrero negro.
# Processing Record 100 of Set 1 | bolshaya dzhalga.
# Processing Record 101 of Set 1 | sondrio.
# Processing Record 102 of Set 1 | kholtoson.
# Processing Record 103 of Set 1 | vila.
# Processing Record 104 of Set 1 | lorengau.
# Processing Record 105 of Set 1 | marsaxlokk.
# Processing Record 106 of Set 1 | harper.
# Processing Record 107 of Set 1 | arraial do cabo.
# Processing Record 108 of Set 1 | hovd.
# Processing Record 109 of Set 1 | benxi.
# City not found, skipping...
# Processing Record 110 of Set 1 | caravelas.
# Processing Record 111 of Set 1 | yulara.
# Processing Record 112 of Set 1 | cape town.
# Processing Record 113 of Set 1 | padron.
# City not found, skipping...
# Processing Record 114 of Set 1 | klaksvik.
# Processing Record 115 of Set 1 | serowe.
# Processing Record 116 of Set 1 | tanout.
# Processing Record 117 of Set 1 | grindavik.
# City not found, skipping...
# Processing Record 118 of Set 1 | kapaa.
# Processing Record 119 of Set 1 | clyde river.
# Processing Record 120 of Set 1 | port-cartier.
# Processing Record 121 of Set 1 | georgetown.
# Processing Record 122 of Set 1 | upernavik.
# Processing Record 123 of Set 1 | chuy.
# Processing Record 124 of Set 1 | vaasa.
# Processing Record 125 of Set 1 | cidreira.
# Processing Record 126 of Set 1 | kavaratti.
# Processing Record 127 of Set 1 | san andres.
# Processing Record 128 of Set 1 | mogadishu.
# City not found, skipping...
# Processing Record 129 of Set 1 | port alfred.
# Processing Record 130 of Set 1 | bandarbeyla.
# Processing Record 131 of Set 1 | sao filipe.
# Processing Record 132 of Set 1 | sao joao da barra.
# Processing Record 133 of Set 1 | pavullo nel frignano.
# Processing Record 134 of Set 1 | jiazi.
# Processing Record 135 of Set 1 | kuusamo.
# Processing Record 136 of Set 1 | mjolby.
# Processing Record 137 of Set 1 | porto walter.
# Processing Record 138 of Set 1 | new norfolk.
# Processing Record 139 of Set 1 | bambous virieux.
# Processing Record 140 of Set 1 | tamiahua.
# Processing Record 141 of Set 1 | tiksi.
# Processing Record 142 of Set 1 | cherskiy.
# Processing Record 143 of Set 1 | porbandar.
# Processing Record 144 of Set 1 | marigot.
# Processing Record 145 of Set 1 | galveston.
# Processing Record 146 of Set 1 | dongsheng.
# Processing Record 147 of Set 1 | talcahuano.
# Processing Record 148 of Set 1 | vila velha.
# Processing Record 149 of Set 1 | mweka.
# Processing Record 150 of Set 1 | arroyo.
# Processing Record 151 of Set 1 | jardim.
# Processing Record 152 of Set 1 | tumsar.
# Processing Record 153 of Set 1 | pirovskoye.
# Processing Record 154 of Set 1 | severo-kurilsk.
# Processing Record 155 of Set 1 | lampazos de naranjo.
# Processing Record 156 of Set 1 | havoysund.
# Processing Record 157 of Set 1 | grand gaube.
# City not found, skipping...
# Processing Record 158 of Set 1 | qaanaaq.
# Processing Record 159 of Set 1 | sistranda.
# Processing Record 160 of Set 1 | ribeira grande.
# Processing Record 161 of Set 1 | victoria.
# Processing Record 162 of Set 1 | changping.
# Processing Record 163 of Set 1 | kailua.
# Processing Record 164 of Set 1 | winslow.
# Processing Record 165 of Set 1 | nyuksenitsa.
# Processing Record 166 of Set 1 | ambulu.
# Processing Record 167 of Set 1 | leningradskiy.
# Processing Record 168 of Set 1 | natal.
# Processing Record 169 of Set 1 | saint-pierre.
# Processing Record 170 of Set 1 | pedernales.
# Processing Record 171 of Set 1 | oranjemund.
# Processing Record 172 of Set 1 | luderitz.
# Processing Record 173 of Set 1 | evensk.
# Processing Record 174 of Set 1 | salta.
# Processing Record 175 of Set 1 | hithadhoo.
# Processing Record 176 of Set 1 | ketchikan.
# City not found, skipping...
# Processing Record 177 of Set 1 | kununurra.
# Processing Record 178 of Set 1 | prado.
# Processing Record 179 of Set 1 | ottawa.
# City not found, skipping...
# Processing Record 180 of Set 1 | payo.
# Processing Record 181 of Set 1 | tomatlan.
# Processing Record 182 of Set 1 | anloga.
# Processing Record 183 of Set 1 | williams lake.
# Processing Record 184 of Set 1 | husavik.
# Processing Record 185 of Set 1 | redmond.
# Processing Record 186 of Set 1 | nemuro.
# Processing Record 187 of Set 1 | locri.
# Processing Record 188 of Set 1 | najran.
# City not found, skipping...
# Processing Record 189 of Set 1 | oga.
# Processing Record 190 of Set 1 | poum.
# City not found, skipping...
# Processing Record 191 of Set 1 | tura.
# Processing Record 192 of Set 1 | chicla.
# Processing Record 193 of Set 1 | poya.
# Processing Record 194 of Set 1 | tasiilaq.
# Processing Record 195 of Set 1 | doha.
# Processing Record 196 of Set 1 | manoel urbano.
# Processing Record 197 of Set 1 | hofn.
# City not found, skipping...
# Processing Record 198 of Set 1 | bilma.
# Processing Record 199 of Set 1 | hami.
# Processing Record 200 of Set 1 | general roca.
# Processing Record 201 of Set 1 | koumac.
# Processing Record 202 of Set 1 | huarmey.
# Processing Record 203 of Set 1 | sorland.
# Processing Record 204 of Set 1 | sabha.
# Processing Record 205 of Set 1 | marsa matruh.
# Processing Record 206 of Set 1 | turayf.
# Processing Record 207 of Set 1 | beira.
# City not found, skipping...
# Processing Record 208 of Set 1 | esperance.
# City not found, skipping...
# Processing Record 209 of Set 1 | san patricio.
# Processing Record 210 of Set 1 | ojinaga.
# Processing Record 211 of Set 1 | talnakh.
# Processing Record 212 of Set 1 | laguna.
# Processing Record 213 of Set 1 | hilo.
# Processing Record 214 of Set 1 | iqaluit.
# Processing Record 215 of Set 1 | palmer.
# Processing Record 216 of Set 1 | isangel.
# Processing Record 217 of Set 1 | pangody.
# Processing Record 218 of Set 1 | reo.
# Processing Record 219 of Set 1 | formosa do rio preto.
# Processing Record 220 of Set 1 | muravlenko.
# Processing Record 221 of Set 1 | linxia.
# City not found, skipping...
# Processing Record 222 of Set 1 | sarmanovo.
# Processing Record 223 of Set 1 | zhob.
# Processing Record 224 of Set 1 | lata.
# Processing Record 225 of Set 1 | longyearbyen.
# Processing Record 226 of Set 1 | taoudenni.
# City not found, skipping...
# Processing Record 227 of Set 1 | maniitsoq.
# Processing Record 228 of Set 1 | barra patuca.
# Processing Record 229 of Set 1 | innisfail.
# Processing Record 230 of Set 1 | yelnya.
# Processing Record 231 of Set 1 | ulaanbaatar.
# Processing Record 232 of Set 1 | gboko.
# Processing Record 233 of Set 1 | chandbali.
# Processing Record 234 of Set 1 | faanui.
# Processing Record 235 of Set 1 | jacareacanga.
# City not found, skipping...
# City not found, skipping...
# Processing Record 236 of Set 1 | ponta do sol.
# Processing Record 237 of Set 1 | sassandra.
# Processing Record 238 of Set 1 | atar.
# Processing Record 239 of Set 1 | capitao poco.
# Processing Record 240 of Set 1 | port shepstone.
# Processing Record 241 of Set 1 | cayenne.
# Processing Record 242 of Set 1 | provideniya.
# Processing Record 243 of Set 1 | saskylakh.
# Processing Record 244 of Set 1 | peleduy.
# Processing Record 245 of Set 1 | chalmette.
# Processing Record 246 of Set 1 | antsohihy.
# Processing Record 247 of Set 1 | kungurtug.
# Processing Record 248 of Set 1 | misratah.
# Processing Record 249 of Set 1 | airai.
# Processing Record 250 of Set 1 | kamaishi.
# Processing Record 251 of Set 1 | lavrentiya.
# Processing Record 252 of Set 1 | yuzhno-kurilsk.
# Processing Record 253 of Set 1 | coruripe.
# Processing Record 254 of Set 1 | torbay.
# Processing Record 255 of Set 1 | batagay-alyta.
# Processing Record 256 of Set 1 | kysyl-syr.
# Processing Record 257 of Set 1 | chara.
# Processing Record 258 of Set 1 | touros.
# Processing Record 259 of Set 1 | lagoa.
# Processing Record 260 of Set 1 | nantucket.
# Processing Record 261 of Set 1 | ulladulla.
# Processing Record 262 of Set 1 | palu.
# Processing Record 263 of Set 1 | cravo norte.
# Processing Record 264 of Set 1 | tigre.
# Processing Record 265 of Set 1 | ust-nera.
# Processing Record 266 of Set 1 | florianopolis.
# Processing Record 267 of Set 1 | deputatskiy.
# Processing Record 268 of Set 1 | san miguel de cauri.
# Processing Record 269 of Set 1 | acapulco.
# Processing Record 270 of Set 1 | kaka.
# Processing Record 271 of Set 1 | barroso.
# Processing Record 272 of Set 1 | msowero.
# City not found, skipping...
# City not found, skipping...
# Processing Record 273 of Set 1 | rawson.
# Processing Record 274 of Set 1 | ilulissat.
# Processing Record 275 of Set 1 | vestmanna.
# Processing Record 276 of Set 1 | angoche.
# Processing Record 277 of Set 1 | dicabisagan.
# City not found, skipping...
# Processing Record 278 of Set 1 | kieta.
# Processing Record 279 of Set 1 | saint anthony.
# Processing Record 280 of Set 1 | saint-philippe.
# Processing Record 281 of Set 1 | teguldet.
# Processing Record 282 of Set 1 | esna.
# City not found, skipping...
# Processing Record 283 of Set 1 | nishihara.
# City not found, skipping...
# Processing Record 284 of Set 1 | bontang.
# Processing Record 285 of Set 1 | denizli.
# Processing Record 286 of Set 1 | xining.
# Processing Record 287 of Set 1 | fereydun kenar.
# Processing Record 288 of Set 1 | sosua.
# Processing Record 289 of Set 1 | drumheller.
# Processing Record 290 of Set 1 | seddon.
# Processing Record 291 of Set 1 | mae sai.
# Processing Record 292 of Set 1 | madang.
# Processing Record 293 of Set 1 | ucluelet.
# Processing Record 294 of Set 1 | oran.
# Processing Record 295 of Set 1 | felanitx.
# Processing Record 296 of Set 1 | khatanga.
# Processing Record 297 of Set 1 | okhotsk.
# Processing Record 298 of Set 1 | aitape.
# Processing Record 299 of Set 1 | bernburg.
# Processing Record 300 of Set 1 | mahebourg.
# Processing Record 301 of Set 1 | armidale.
# Processing Record 302 of Set 1 | tsumeb.
# Processing Record 303 of Set 1 | salinopolis.
# Processing Record 304 of Set 1 | roald.
# Processing Record 305 of Set 1 | lanzhou.
# Processing Record 306 of Set 1 | minas.
# Processing Record 307 of Set 1 | lazaro cardenas.
# Processing Record 308 of Set 1 | venado tuerto.
# Processing Record 309 of Set 1 | diu.
# Processing Record 310 of Set 1 | virginia beach.
# Processing Record 311 of Set 1 | kruisfontein.
# City not found, skipping...
# City not found, skipping...
# Processing Record 312 of Set 1 | zapolyarnyy.
# Processing Record 313 of Set 1 | aqtobe.
# Processing Record 314 of Set 1 | teeli.
# Processing Record 315 of Set 1 | rocha.
# Processing Record 316 of Set 1 | beloha.
# Processing Record 317 of Set 1 | nekhayevskiy.
# Processing Record 318 of Set 1 | gangapur.
# Processing Record 319 of Set 1 | college.
# Processing Record 320 of Set 1 | north bend.
# Processing Record 321 of Set 1 | balaipungut.
# Processing Record 322 of Set 1 | cooma.
# Processing Record 323 of Set 1 | sisimiut.
# City not found, skipping...
# Processing Record 324 of Set 1 | urgut.
# City not found, skipping...
# Processing Record 325 of Set 1 | ust-uda.
# Processing Record 326 of Set 1 | scarborough.
# Processing Record 327 of Set 1 | celestun.
# City not found, skipping...
# Processing Record 328 of Set 1 | nizwa.
# Processing Record 329 of Set 1 | chaykovskiy.
# Processing Record 330 of Set 1 | quatre cocos.
# Processing Record 331 of Set 1 | usinsk.
# Processing Record 332 of Set 1 | geraldton.
# Processing Record 333 of Set 1 | nome.
# Processing Record 334 of Set 1 | naze.
# Processing Record 335 of Set 1 | balkhash.
# Processing Record 336 of Set 1 | lasa.
# City not found, skipping...
# Processing Record 337 of Set 1 | kahului.
# Processing Record 338 of Set 1 | richards bay.
# Processing Record 339 of Set 1 | belmonte.
# Processing Record 340 of Set 1 | nayoro.
# Processing Record 341 of Set 1 | almaty.
# Processing Record 342 of Set 1 | buraydah.
# Processing Record 343 of Set 1 | inuvik.
# Processing Record 344 of Set 1 | nueva loja.
# Processing Record 345 of Set 1 | bellmead.
# Processing Record 346 of Set 1 | port hardy.
# City not found, skipping...
# City not found, skipping...
# Processing Record 347 of Set 1 | hirara.
# Processing Record 348 of Set 1 | marienburg.
# Processing Record 349 of Set 1 | hambantota.
# Processing Record 350 of Set 1 | iracoubo.
# Processing Record 351 of Set 1 | kizukuri.
# Processing Record 352 of Set 1 | kabinda.
# Processing Record 353 of Set 1 | char bhadrasan.
# City not found, skipping...
# City not found, skipping...
# Processing Record 354 of Set 1 | hualmay.
# Processing Record 355 of Set 1 | ende.
# Processing Record 356 of Set 1 | saint-leu.
# Processing Record 357 of Set 1 | southampton.
# Processing Record 358 of Set 1 | baymak.
# Processing Record 359 of Set 1 | snina.
# City not found, skipping...
# Processing Record 360 of Set 1 | mount gambier.
# Processing Record 361 of Set 1 | lusaka.
# Processing Record 362 of Set 1 | warrnambool.
# Processing Record 363 of Set 1 | ponazyrevo.
# Processing Record 364 of Set 1 | mehamn.
# Processing Record 365 of Set 1 | shache.
# Processing Record 366 of Set 1 | lahij.
# Processing Record 367 of Set 1 | wonogiri.
# Processing Record 368 of Set 1 | trat.
# Processing Record 369 of Set 1 | fort nelson.
# Processing Record 370 of Set 1 | necochea.
# City not found, skipping...
# Processing Record 371 of Set 1 | whitehorse.
# Processing Record 372 of Set 1 | atbasar.
# Processing Record 373 of Set 1 | manicore.
# Processing Record 374 of Set 1 | gambo.
# Processing Record 375 of Set 1 | vao.
# Processing Record 376 of Set 1 | aksu.
# Processing Record 377 of Set 1 | rock sound.
# Processing Record 378 of Set 1 | igarka.
# City not found, skipping...
# City not found, skipping...
# Processing Record 379 of Set 1 | beringovskiy.
# Processing Record 380 of Set 1 | shimoda.
# Processing Record 381 of Set 1 | kenai.
# Processing Record 382 of Set 1 | meulaboh.
# Processing Record 383 of Set 1 | nanakuli.
# Processing Record 384 of Set 1 | sorrento.
# Processing Record 385 of Set 1 | lebyazhye.
# Processing Record 386 of Set 1 | shreveport.
# Processing Record 387 of Set 1 | taltal.
# Processing Record 388 of Set 1 | sofiyivka.
# Processing Record 389 of Set 1 | los llanos de aridane.
# Processing Record 390 of Set 1 | alofi.
# Processing Record 391 of Set 1 | constantine.
# Processing Record 392 of Set 1 | kupang.
# City not found, skipping...
# Processing Record 393 of Set 1 | nuuk.
# Processing Record 394 of Set 1 | inhambane.
# Processing Record 395 of Set 1 | port lincoln.
# Processing Record 396 of Set 1 | sampit.
# Processing Record 397 of Set 1 | jalingo.
# Processing Record 398 of Set 1 | morgan city.
# Processing Record 399 of Set 1 | kutum.
# Processing Record 400 of Set 1 | buchanan.
# Processing Record 401 of Set 1 | japura.
# Processing Record 402 of Set 1 | sabang.
# City not found, skipping...
# Processing Record 403 of Set 1 | calatayud.
# Processing Record 404 of Set 1 | marawi.
# Processing Record 405 of Set 1 | madera.
# Processing Record 406 of Set 1 | perth.
# City not found, skipping...
# Processing Record 407 of Set 1 | mountain home.
# City not found, skipping...
# Processing Record 408 of Set 1 | constitucion.
# Processing Record 409 of Set 1 | marsh harbour.
# Processing Record 410 of Set 1 | chumphon.
# Processing Record 411 of Set 1 | niono.
# Processing Record 412 of Set 1 | adre.
# Processing Record 413 of Set 1 | gizo.
# Processing Record 414 of Set 1 | viedma.
# Processing Record 415 of Set 1 | otane.
# Processing Record 416 of Set 1 | christchurch.
# Processing Record 417 of Set 1 | campina grande do sul.
# Processing Record 418 of Set 1 | jaru.
# Processing Record 419 of Set 1 | monte alegre.
# Processing Record 420 of Set 1 | ugoofaaru.
# Processing Record 421 of Set 1 | san cristobal.
# Processing Record 422 of Set 1 | alyangula.
# Processing Record 423 of Set 1 | marana.
# Processing Record 424 of Set 1 | manga.
# Processing Record 425 of Set 1 | czersk.
# Processing Record 426 of Set 1 | vardo.
# Processing Record 427 of Set 1 | herat.
# Processing Record 428 of Set 1 | dwarka.
# Processing Record 429 of Set 1 | aksarka.
# Processing Record 430 of Set 1 | gucheng.
# Processing Record 431 of Set 1 | buin.
# Processing Record 432 of Set 1 | barranca.
# Processing Record 433 of Set 1 | svetlaya.
# Processing Record 434 of Set 1 | passo de camaragibe.
# Processing Record 435 of Set 1 | antofagasta.
# Processing Record 436 of Set 1 | arambagh.
# Processing Record 437 of Set 1 | jieshi.
# Processing Record 438 of Set 1 | barcelos.
# Processing Record 439 of Set 1 | cockburn town.
# Processing Record 440 of Set 1 | emerald.
# Processing Record 441 of Set 1 | bowen.
# Processing Record 442 of Set 1 | wagar.
# Processing Record 443 of Set 1 | soyo.
# City not found, skipping...
# Processing Record 444 of Set 1 | magdagachi.
# Processing Record 445 of Set 1 | tarko-sale.
# Processing Record 446 of Set 1 | malindi.
# Processing Record 447 of Set 1 | northam.
# Processing Record 448 of Set 1 | tyumentsevo.
# City not found, skipping...
# Processing Record 449 of Set 1 | norway.
# Processing Record 450 of Set 1 | san carlos de bariloche.
# Processing Record 451 of Set 1 | parintins.
# Processing Record 452 of Set 1 | pozo colorado.
# Processing Record 453 of Set 1 | afyonkarahisar.
# Processing Record 454 of Set 1 | nioki.
# Processing Record 455 of Set 1 | ballina.
# Processing Record 456 of Set 1 | quang ngai.
# Processing Record 457 of Set 1 | samana.
# Processing Record 458 of Set 1 | elbasan.
# Processing Record 459 of Set 1 | auki.
# Processing Record 460 of Set 1 | iquique.
# Processing Record 461 of Set 1 | konstantinovka.
# Processing Record 462 of Set 1 | sheridan.
# Processing Record 463 of Set 1 | kodinsk.
# Processing Record 464 of Set 1 | moron.
# Processing Record 465 of Set 1 | solnechnyy.
# Processing Record 466 of Set 1 | batemans bay.
# Processing Record 467 of Set 1 | hobyo.
# Processing Record 468 of Set 1 | agadez.
# Processing Record 469 of Set 1 | maxixe.
# City not found, skipping...
# Processing Record 470 of Set 1 | hohhot.
# Processing Record 471 of Set 1 | forio.
# Processing Record 472 of Set 1 | paita.
# Processing Record 473 of Set 1 | la ronge.
# Processing Record 474 of Set 1 | zhelyabovka.
# Processing Record 475 of Set 1 | honiara.
# Processing Record 476 of Set 1 | mahishadal.
# Processing Record 477 of Set 1 | mackay.
# Processing Record 478 of Set 1 | monrovia.
# Processing Record 479 of Set 1 | arkhara.
# Processing Record 480 of Set 1 | beohari.
# Processing Record 481 of Set 1 | luwuk.
# Processing Record 482 of Set 1 | terra rica.
# Processing Record 483 of Set 1 | komsomolskiy.
# Processing Record 484 of Set 1 | egvekinot.
# Processing Record 485 of Set 1 | hailin.
# Processing Record 486 of Set 1 | freeport.
# City not found, skipping...
# City not found, skipping...
# City not found, skipping...
# Processing Record 487 of Set 1 | tebingtinggi.
# City not found, skipping...
# Processing Record 488 of Set 1 | verkhnevilyuysk.
# Processing Record 489 of Set 1 | iguape.
# Processing Record 490 of Set 1 | chumikan.
# Processing Record 491 of Set 1 | tual.
# Processing Record 492 of Set 1 | listowel.
# Processing Record 493 of Set 1 | ngunguru.
# Processing Record 494 of Set 1 | palana.
# Processing Record 495 of Set 1 | barstow.
# Processing Record 496 of Set 1 | ruidoso.
# Processing Record 497 of Set 1 | fomboni.
# Processing Record 498 of Set 1 | riviera beach.
# Processing Record 499 of Set 1 | bonavista.
# Processing Record 500 of Set 1 | west plains.
# Processing Record 501 of Set 1 | banda aceh.
# City not found, skipping...
# Processing Record 502 of Set 1 | polovinnoye.
# Processing Record 503 of Set 1 | suhbaatar.
# Processing Record 504 of Set 1 | pendleton.
# Processing Record 505 of Set 1 | zyryanka.
# Processing Record 506 of Set 1 | zachary.
# Processing Record 507 of Set 1 | hella.
# Processing Record 508 of Set 1 | lishu.
# Processing Record 509 of Set 1 | hervey bay.
# Processing Record 510 of Set 1 | galegos.
# Processing Record 511 of Set 1 | ostrovnoy.
# Processing Record 512 of Set 1 | bambanglipuro.
# Processing Record 513 of Set 1 | zhangye.
# Processing Record 514 of Set 1 | saint-francois.
# City not found, skipping...
# Processing Record 515 of Set 1 | noyabrsk.
# City not found, skipping...
# Processing Record 516 of Set 1 | taonan.
# Processing Record 517 of Set 1 | raudeberg.
# Processing Record 518 of Set 1 | rosarno.
# Processing Record 519 of Set 1 | tiznit.
# Processing Record 520 of Set 1 | coahuayana.
# Processing Record 521 of Set 1 | jiayuguan.
# Processing Record 522 of Set 1 | joao pinheiro.
# Processing Record 523 of Set 1 | sebezh.
# Processing Record 524 of Set 1 | karratha.
# Processing Record 525 of Set 1 | ahipara.
# Processing Record 526 of Set 1 | twin falls.
# Processing Record 527 of Set 1 | eregli.
# Processing Record 528 of Set 1 | el tambo.
# Processing Record 529 of Set 1 | rudraprayag.
# Processing Record 530 of Set 1 | the valley.
# Processing Record 531 of Set 1 | umm kaddadah.
# Processing Record 532 of Set 1 | skala fourkas.
# Processing Record 533 of Set 1 | den helder.
# Processing Record 534 of Set 1 | kazerun.
# Processing Record 535 of Set 1 | sun valley.
# Processing Record 536 of Set 1 | mahajanga.
# City not found, skipping...
# Processing Record 537 of Set 1 | waris aliganj.
# Processing Record 538 of Set 1 | pathein.
# Processing Record 539 of Set 1 | turukhansk.
# Processing Record 540 of Set 1 | ciudad bolivar.
# City not found, skipping...
# Processing Record 541 of Set 1 | kegums.
# Processing Record 542 of Set 1 | north las vegas.
# Processing Record 543 of Set 1 | annau.
# Processing Record 544 of Set 1 | bien hoa.
# Processing Record 545 of Set 1 | road town.
# Processing Record 546 of Set 1 | gat.
# Processing Record 547 of Set 1 | hirekerur.
# Processing Record 548 of Set 1 | yarada.
# Processing Record 549 of Set 1 | zemio.
# Processing Record 550 of Set 1 | ocampo.
# Processing Record 551 of Set 1 | jodhpur.
# Processing Record 552 of Set 1 | chhagalnaiya.
# Processing Record 553 of Set 1 | biltine.
# Processing Record 554 of Set 1 | vila franca do campo.
# Processing Record 555 of Set 1 | boa vista.
# Processing Record 556 of Set 1 | alugan.
# Processing Record 557 of Set 1 | havre-saint-pierre.
# Processing Record 558 of Set 1 | tautira.
# Processing Record 559 of Set 1 | whitianga.
# Processing Record 560 of Set 1 | broome.
# Processing Record 561 of Set 1 | namibe.
# Processing Record 562 of Set 1 | opatija.
# Processing Record 563 of Set 1 | tjome.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": citynew,
    "Cloudiness": cloud,
    "Country": country,
    "Date" : date,
    "Humidity" : humidity,
    "Lat": lat,
    "Lon" : lon,
    "Max Temp" : maxtemp,
    "Wind Speed" :windspeed 
    
}

weather_data = pd.DataFrame(weather_dict)

weather_data.head()

weather_data.to_csv("weatherfile.csv")

# %%
weather_data.count()
# Out:
# City          563
# Cloudiness    563
# Country       563
# Date          563
# Humidity      563
# Lat           563
# Lon           563
# Max Temp      563
# Wind Speed    563
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o")

# Incorporate the other graph properties

current_time = datetime.now()

current_date = current_time.strftime('%m/%d/%Y')

plt.title(f"City Latitude vs. Max Temperature ({current_date})")

plt.ylabel("Max Temperature (Fahrenheit)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure

plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o")

# Incorporate the other graph properties
current_time = datetime.now()

current_date = current_time.strftime('%m/%d/%Y')

plt.title(f"City Latitude vs. Humidity ({current_date})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o")

# Incorporate the other graph properties

current_time = datetime.now()

current_date = current_time.strftime('%m/%d/%Y')

plt.title(f"City Latitude vs. Cloudiness ({current_date})")


plt.title("Cloudiness in World Cities")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o")

# Incorporate the other graph properties


current_time = datetime.now()

current_date = current_time.strftime('%m/%d/%Y')

plt.title(f"City Latitude vs. Wind Speed ({current_date})")


plt.title("Wind Speed in World Cities")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Wind Speed.png")

# Show plot
plt.show()
