# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from pprint import pprint
# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Start building URL


url = "http://api.openweathermap.org/data/2.5/weather?"
#city = "Bujumbura"
units = "imperial"

query_url = f"{url}appid={api_key}&q={city}&units={units}"


# Create empty List to store the values

lat=[]
lon = []
maxtemp = []
cloud = []
windspeed = []
humidity = []
citynew = []
date = []
country = []

#Running loop for all cities

for city in cities:
    
    # Jso-ified the API response
    
    query_url = f"{url}appid={api_key}&q={city}&units={units}"
    response = requests.get(query_url).json()
    
    #Error checking for cities not found
    
    if response["cod"] == "404":
        print("City not found, skipping...")
        
    
    #building list for found cities.
    
    else:
        
        
        value =1 
        
        print(f"Processing Record {value} of Set 1 | {city}.")
        
        #Append the blanc list
        
        lat.append(response['coord']['lat'])
        
        lon.append(response['coord']['lon'])
        
        maxtemp.append(response['main']['temp_max'])
        
        cloud.append(response['clouds']['all'])
        
        windspeed.append(response['wind']['speed'])
        
        humidity.append(response['main']['humidity'])
        
        citynew.append(response['name'])
        
        date.append(response['dt'])
        
        country.append(response['sys']['country']) 
        
        value = value+1
# Out:
# Processing Record 1 of Set 1 | capitan bado.
# City not found, skipping...
# Processing Record 1 of Set 1 | georgetown.
# Processing Record 1 of Set 1 | mataura.
# Processing Record 1 of Set 1 | rikitea.
# Processing Record 1 of Set 1 | florianopolis.
# Processing Record 1 of Set 1 | saint-philippe.
# Processing Record 1 of Set 1 | pevek.
# Processing Record 1 of Set 1 | touros.
# Processing Record 1 of Set 1 | punta arenas.
# Processing Record 1 of Set 1 | hithadhoo.
# Processing Record 1 of Set 1 | saint george.
# City not found, skipping...
# Processing Record 1 of Set 1 | ugoofaaru.
# Processing Record 1 of Set 1 | atuona.
# Processing Record 1 of Set 1 | ixtapa.
# Processing Record 1 of Set 1 | benghazi.
# Processing Record 1 of Set 1 | rawson.
# Processing Record 1 of Set 1 | karratha.
# Processing Record 1 of Set 1 | avarua.
# Processing Record 1 of Set 1 | ushuaia.
# Processing Record 1 of Set 1 | kendari.
# Processing Record 1 of Set 1 | upernavik.
# Processing Record 1 of Set 1 | tomigusuku.
# Processing Record 1 of Set 1 | carnarvon.
# Processing Record 1 of Set 1 | santa rosa.
# Processing Record 1 of Set 1 | east london.
# Processing Record 1 of Set 1 | petawawa.
# Processing Record 1 of Set 1 | albany.
# Processing Record 1 of Set 1 | kadirli.
# Processing Record 1 of Set 1 | pacific grove.
# Processing Record 1 of Set 1 | saint-augustin.
# Processing Record 1 of Set 1 | skelleftea.
# Processing Record 1 of Set 1 | meulaboh.
# Processing Record 1 of Set 1 | nikolskoye.
# Processing Record 1 of Set 1 | clyde river.
# Processing Record 1 of Set 1 | naron.
# Processing Record 1 of Set 1 | nhulunbuy.
# Processing Record 1 of Set 1 | buala.
# Processing Record 1 of Set 1 | half moon bay.
# Processing Record 1 of Set 1 | cairns.
# Processing Record 1 of Set 1 | lagoa.
# Processing Record 1 of Set 1 | busselton.
# Processing Record 1 of Set 1 | sampit.
# Processing Record 1 of Set 1 | chegdomyn.
# Processing Record 1 of Set 1 | dikson.
# Processing Record 1 of Set 1 | tacna.
# Processing Record 1 of Set 1 | kapaa.
# Processing Record 1 of Set 1 | slobodskoy.
# Processing Record 1 of Set 1 | kodiak.
# City not found, skipping...
# City not found, skipping...
# City not found, skipping...
# Processing Record 1 of Set 1 | ponta do sol.
# Processing Record 1 of Set 1 | tuktoyaktuk.
# Processing Record 1 of Set 1 | cherskiy.
# Processing Record 1 of Set 1 | ribeira grande.
# Processing Record 1 of Set 1 | tasiilaq.
# Processing Record 1 of Set 1 | puerto ayora.
# Processing Record 1 of Set 1 | port alfred.
# Processing Record 1 of Set 1 | abnub.
# Processing Record 1 of Set 1 | kamenka.
# Processing Record 1 of Set 1 | arraial do cabo.
# Processing Record 1 of Set 1 | presidencia roque saenz pena.
# Processing Record 1 of Set 1 | san patricio.
# Processing Record 1 of Set 1 | sao joao da barra.
# City not found, skipping...
# Processing Record 1 of Set 1 | newport.
# Processing Record 1 of Set 1 | mezen.
# City not found, skipping...
# Processing Record 1 of Set 1 | jamestown.
# City not found, skipping...
# Processing Record 1 of Set 1 | damghan.
# Processing Record 1 of Set 1 | ola.
# City not found, skipping...
# Processing Record 1 of Set 1 | hermanus.
# Processing Record 1 of Set 1 | longyearbyen.
# Processing Record 1 of Set 1 | monrovia.
# City not found, skipping...
# Processing Record 1 of Set 1 | moron.
# Processing Record 1 of Set 1 | verkhoyansk.
# Processing Record 1 of Set 1 | hobart.
# Processing Record 1 of Set 1 | sitka.
# Processing Record 1 of Set 1 | barrow.
# City not found, skipping...
# Processing Record 1 of Set 1 | parrita.
# Processing Record 1 of Set 1 | ovalle.
# Processing Record 1 of Set 1 | sisimiut.
# Processing Record 1 of Set 1 | port elizabeth.
# Processing Record 1 of Set 1 | fowa.
# Processing Record 1 of Set 1 | butaritari.
# Processing Record 1 of Set 1 | guerrero negro.
# City not found, skipping...
# Processing Record 1 of Set 1 | new norfolk.
# Processing Record 1 of Set 1 | vardo.
# Processing Record 1 of Set 1 | ambilobe.
# Processing Record 1 of Set 1 | bredasdorp.
# City not found, skipping...
# Processing Record 1 of Set 1 | vaini.
# Processing Record 1 of Set 1 | basoko.
# Processing Record 1 of Set 1 | cape town.
# Processing Record 1 of Set 1 | byron bay.
# Processing Record 1 of Set 1 | novyy urengoy.
# Processing Record 1 of Set 1 | sahuaripa.
# Processing Record 1 of Set 1 | pacsa.
# Processing Record 1 of Set 1 | merauke.
# Processing Record 1 of Set 1 | vao.
# Processing Record 1 of Set 1 | turangi.
# Processing Record 1 of Set 1 | bacungan.
# Processing Record 1 of Set 1 | huaraz.
# Processing Record 1 of Set 1 | la ronge.
# Processing Record 1 of Set 1 | mayo.
# Processing Record 1 of Set 1 | bluff.
# Processing Record 1 of Set 1 | port lincoln.
# City not found, skipping...
# Processing Record 1 of Set 1 | bokovskaya.
# City not found, skipping...
# City not found, skipping...
# City not found, skipping...
# City not found, skipping...
# City not found, skipping...
# Processing Record 1 of Set 1 | yerbogachen.
# Processing Record 1 of Set 1 | ayan.
# City not found, skipping...
# Processing Record 1 of Set 1 | alice springs.
# Processing Record 1 of Set 1 | tucurui.
# Processing Record 1 of Set 1 | huarmey.
# Processing Record 1 of Set 1 | ilulissat.
# Processing Record 1 of Set 1 | puerto escondido.
# Processing Record 1 of Set 1 | timmins.
# Processing Record 1 of Set 1 | kavaratti.
# Processing Record 1 of Set 1 | sinnamary.
# Processing Record 1 of Set 1 | hamilton.
# Processing Record 1 of Set 1 | araripe.
# Processing Record 1 of Set 1 | manono.
# Processing Record 1 of Set 1 | belmonte.
# Processing Record 1 of Set 1 | mar del plata.
# Processing Record 1 of Set 1 | russell.
# Processing Record 1 of Set 1 | nicoya.
# Processing Record 1 of Set 1 | vallenar.
# Processing Record 1 of Set 1 | mujiayingzi.
# Processing Record 1 of Set 1 | moba.
# Processing Record 1 of Set 1 | jacareacanga.
# Processing Record 1 of Set 1 | college.
# Processing Record 1 of Set 1 | perth.
# City not found, skipping...
# Processing Record 1 of Set 1 | iqaluit.
# Processing Record 1 of Set 1 | emba.
# City not found, skipping...
# Processing Record 1 of Set 1 | santa ana.
# Processing Record 1 of Set 1 | zhengjiatun.
# Processing Record 1 of Set 1 | ust-tsilma.
# Processing Record 1 of Set 1 | souillac.
# City not found, skipping...
# City not found, skipping...
# Processing Record 1 of Set 1 | sobolevo.
# Processing Record 1 of Set 1 | caucasia.
# Processing Record 1 of Set 1 | tiksi.
# Processing Record 1 of Set 1 | ulladulla.
# Processing Record 1 of Set 1 | port blair.
# Processing Record 1 of Set 1 | faanui.
# Processing Record 1 of Set 1 | vila franca do campo.
# Processing Record 1 of Set 1 | lavrentiya.
# Processing Record 1 of Set 1 | constitucion.
# Processing Record 1 of Set 1 | port-gentil.
# Processing Record 1 of Set 1 | bathsheba.
# Processing Record 1 of Set 1 | valdez.
# Processing Record 1 of Set 1 | cidreira.
# Processing Record 1 of Set 1 | moose factory.
# Processing Record 1 of Set 1 | san jose.
# City not found, skipping...
# Processing Record 1 of Set 1 | wielun.
# Processing Record 1 of Set 1 | krutikha.
# Processing Record 1 of Set 1 | saskylakh.
# Processing Record 1 of Set 1 | bowen.
# Processing Record 1 of Set 1 | yellowknife.
# Processing Record 1 of Set 1 | vila velha.
# Processing Record 1 of Set 1 | qaanaaq.
# Processing Record 1 of Set 1 | vesyegonsk.
# Processing Record 1 of Set 1 | bani walid.
# Processing Record 1 of Set 1 | xucheng.
# Processing Record 1 of Set 1 | geraldton.
# Processing Record 1 of Set 1 | thompson.
# Processing Record 1 of Set 1 | jian.
# Processing Record 1 of Set 1 | lebu.
# Processing Record 1 of Set 1 | sao filipe.
# Processing Record 1 of Set 1 | provideniya.
# Processing Record 1 of Set 1 | burgeo.
# Processing Record 1 of Set 1 | pisco.
# Processing Record 1 of Set 1 | mahebourg.
# City not found, skipping...
# Processing Record 1 of Set 1 | chililabombwe.
# Processing Record 1 of Set 1 | tucuman.
# Processing Record 1 of Set 1 | tateyama.
# Processing Record 1 of Set 1 | grand-santi.
# Processing Record 1 of Set 1 | chokurdakh.
# Processing Record 1 of Set 1 | castro.
# City not found, skipping...
# Processing Record 1 of Set 1 | garowe.
# Processing Record 1 of Set 1 | bubaque.
# Processing Record 1 of Set 1 | kuito.
# Processing Record 1 of Set 1 | husavik.
# Processing Record 1 of Set 1 | tikrit.
# Processing Record 1 of Set 1 | rosetown.
# Processing Record 1 of Set 1 | mouila.
# Processing Record 1 of Set 1 | bethel.
# Processing Record 1 of Set 1 | ishigaki.
# Processing Record 1 of Set 1 | avera.
# Processing Record 1 of Set 1 | baykit.
# Processing Record 1 of Set 1 | victoria.
# Processing Record 1 of Set 1 | hilo.
# City not found, skipping...
# Processing Record 1 of Set 1 | birao.
# Processing Record 1 of Set 1 | bambous virieux.
# City not found, skipping...
# Processing Record 1 of Set 1 | rincon.
# Processing Record 1 of Set 1 | flagstaff.
# Processing Record 1 of Set 1 | codrington.
# Processing Record 1 of Set 1 | berlevag.
# City not found, skipping...
# Processing Record 1 of Set 1 | sorland.
# Processing Record 1 of Set 1 | mount gambier.
# Processing Record 1 of Set 1 | bilibino.
# Processing Record 1 of Set 1 | wajir.
# Processing Record 1 of Set 1 | kalmunai.
# Processing Record 1 of Set 1 | narsaq.
# Processing Record 1 of Set 1 | miguel calmon.
# Processing Record 1 of Set 1 | san javier.
# Processing Record 1 of Set 1 | kenai.
# Processing Record 1 of Set 1 | tsabong.
# Processing Record 1 of Set 1 | gniezno.
# Processing Record 1 of Set 1 | kathmandu.
# Processing Record 1 of Set 1 | hasaki.
# City not found, skipping...
# Processing Record 1 of Set 1 | kachug.
# Processing Record 1 of Set 1 | chipata.
# Processing Record 1 of Set 1 | milkovo.
# Processing Record 1 of Set 1 | ouargaye.
# Processing Record 1 of Set 1 | new waterford.
# Processing Record 1 of Set 1 | sanmenxia.
# Processing Record 1 of Set 1 | hornepayne.
# Processing Record 1 of Set 1 | leh.
# Processing Record 1 of Set 1 | saint-joseph.
# Processing Record 1 of Set 1 | san joaquin.
# Processing Record 1 of Set 1 | lata.
# Processing Record 1 of Set 1 | jimeta.
# Processing Record 1 of Set 1 | nemuro.
# Processing Record 1 of Set 1 | goderich.
# Processing Record 1 of Set 1 | correntina.
# Processing Record 1 of Set 1 | polunochnoye.
# Processing Record 1 of Set 1 | yumen.
# Processing Record 1 of Set 1 | kyabe.
# Processing Record 1 of Set 1 | san cristobal.
# Processing Record 1 of Set 1 | katobu.
# Processing Record 1 of Set 1 | porto novo.
# Processing Record 1 of Set 1 | khatanga.
# City not found, skipping...
# City not found, skipping...
# Processing Record 1 of Set 1 | mopti.
# Processing Record 1 of Set 1 | mkushi.
# Processing Record 1 of Set 1 | qiongshan.
# City not found, skipping...
# Processing Record 1 of Set 1 | logrono.
# Processing Record 1 of Set 1 | kirakira.
# Processing Record 1 of Set 1 | caravelas.
# Processing Record 1 of Set 1 | arraias.
# Processing Record 1 of Set 1 | harper.
# Processing Record 1 of Set 1 | weston.
# Processing Record 1 of Set 1 | thinadhoo.
# Processing Record 1 of Set 1 | le port.
# Processing Record 1 of Set 1 | flin flon.
# Processing Record 1 of Set 1 | portland.
# Processing Record 1 of Set 1 | aquiraz.
# City not found, skipping...
# Processing Record 1 of Set 1 | brae.
# City not found, skipping...
# Processing Record 1 of Set 1 | te anau.
# Processing Record 1 of Set 1 | ca mau.
# Processing Record 1 of Set 1 | poum.
# Processing Record 1 of Set 1 | chuy.
# Processing Record 1 of Set 1 | kaitangata.
# Processing Record 1 of Set 1 | kieta.
# Processing Record 1 of Set 1 | stromness.
# Processing Record 1 of Set 1 | zhezkazgan.
# Processing Record 1 of Set 1 | junction city.
# Processing Record 1 of Set 1 | richards bay.
# City not found, skipping...
# Processing Record 1 of Set 1 | ambovombe.
# Processing Record 1 of Set 1 | stavropol.
# Processing Record 1 of Set 1 | rabo de peixe.
# Processing Record 1 of Set 1 | egvekinot.
# Processing Record 1 of Set 1 | port augusta.
# Processing Record 1 of Set 1 | klaksvik.
# Processing Record 1 of Set 1 | saint anthony.
# Processing Record 1 of Set 1 | road town.
# Processing Record 1 of Set 1 | lompoc.
# Processing Record 1 of Set 1 | xixiang.
# Processing Record 1 of Set 1 | waverley.
# Processing Record 1 of Set 1 | sukumo.
# Processing Record 1 of Set 1 | mari-turek.
# Processing Record 1 of Set 1 | cayenne.
# Processing Record 1 of Set 1 | wanning.
# City not found, skipping...
# Processing Record 1 of Set 1 | pathein.
# Processing Record 1 of Set 1 | ornskoldsvik.
# Processing Record 1 of Set 1 | san carlos de bariloche.
# Processing Record 1 of Set 1 | houma.
# Processing Record 1 of Set 1 | deputatskiy.
# Processing Record 1 of Set 1 | fortuna.
# Processing Record 1 of Set 1 | port hawkesbury.
# Processing Record 1 of Set 1 | vestmannaeyjar.
# Processing Record 1 of Set 1 | clyde.
# Processing Record 1 of Set 1 | kaeo.
# Processing Record 1 of Set 1 | sharjah.
# Processing Record 1 of Set 1 | mananjary.
# City not found, skipping...
# Processing Record 1 of Set 1 | northam.
# Processing Record 1 of Set 1 | yulara.
# Processing Record 1 of Set 1 | teguise.
# Processing Record 1 of Set 1 | playa vicente.
# Processing Record 1 of Set 1 | saldanha.
# Processing Record 1 of Set 1 | caramay.
# Processing Record 1 of Set 1 | ronneby.
# Processing Record 1 of Set 1 | ancud.
# Processing Record 1 of Set 1 | ruiru.
# Processing Record 1 of Set 1 | makat.
# Processing Record 1 of Set 1 | grindavik.
# Processing Record 1 of Set 1 | shingu.
# Processing Record 1 of Set 1 | kargasok.
# Processing Record 1 of Set 1 | jurm.
# Processing Record 1 of Set 1 | kloulklubed.
# Processing Record 1 of Set 1 | cap-aux-meules.
# Processing Record 1 of Set 1 | chipinge.
# Processing Record 1 of Set 1 | kavieng.
# Processing Record 1 of Set 1 | wamba.
# City not found, skipping...
# Processing Record 1 of Set 1 | konotop.
# Processing Record 1 of Set 1 | airai.
# Processing Record 1 of Set 1 | isangel.
# City not found, skipping...
# Processing Record 1 of Set 1 | nombre de dios.
# Processing Record 1 of Set 1 | manuk mangkaw.
# City not found, skipping...
# City not found, skipping...
# Processing Record 1 of Set 1 | uitenhage.
# Processing Record 1 of Set 1 | esperance.
# Processing Record 1 of Set 1 | beringovskiy.
# Processing Record 1 of Set 1 | axim.
# Processing Record 1 of Set 1 | kuytun.
# Processing Record 1 of Set 1 | lerwick.
# Processing Record 1 of Set 1 | moramanga.
# Processing Record 1 of Set 1 | nuevitas.
# Processing Record 1 of Set 1 | mbekenyera.
# Processing Record 1 of Set 1 | carutapera.
# Processing Record 1 of Set 1 | inuvik.
# Processing Record 1 of Set 1 | washington.
# Processing Record 1 of Set 1 | belaya gora.
# Processing Record 1 of Set 1 | sulangan.
# Processing Record 1 of Set 1 | maniitsoq.
# Processing Record 1 of Set 1 | penzance.
# Processing Record 1 of Set 1 | biharamulo.
# Processing Record 1 of Set 1 | beloha.
# Processing Record 1 of Set 1 | batagay.
# City not found, skipping...
# Processing Record 1 of Set 1 | praia da vitoria.
# Processing Record 1 of Set 1 | cabo san lucas.
# City not found, skipping...
# Processing Record 1 of Set 1 | sanghar.
# Processing Record 1 of Set 1 | katsuura.
# Processing Record 1 of Set 1 | quimper.
# Processing Record 1 of Set 1 | misratah.
# Processing Record 1 of Set 1 | arlit.
# Processing Record 1 of Set 1 | santa fe.
# Processing Record 1 of Set 1 | beloyarskiy.
# Processing Record 1 of Set 1 | simpang.
# Processing Record 1 of Set 1 | kharp.
# Processing Record 1 of Set 1 | piranhas.
# Processing Record 1 of Set 1 | severo-kurilsk.
# Processing Record 1 of Set 1 | bara.
# Processing Record 1 of Set 1 | aykhal.
# Processing Record 1 of Set 1 | ko samui.
# Processing Record 1 of Set 1 | mosquera.
# Processing Record 1 of Set 1 | north platte.
# Processing Record 1 of Set 1 | pandan.
# Processing Record 1 of Set 1 | walvis bay.
# City not found, skipping...
# Processing Record 1 of Set 1 | nanortalik.
# City not found, skipping...
# Processing Record 1 of Set 1 | noumea.
# Processing Record 1 of Set 1 | fairbanks.
# City not found, skipping...
# Processing Record 1 of Set 1 | mayahi.
# Processing Record 1 of Set 1 | kambove.
# Processing Record 1 of Set 1 | hami.
# Processing Record 1 of Set 1 | riyadh.
# City not found, skipping...
# Processing Record 1 of Set 1 | rosetta.
# Processing Record 1 of Set 1 | taos.
# Processing Record 1 of Set 1 | mangrol.
# Processing Record 1 of Set 1 | ylivieska.
# Processing Record 1 of Set 1 | hofn.
# Processing Record 1 of Set 1 | canon city.
# Processing Record 1 of Set 1 | henties bay.
# Processing Record 1 of Set 1 | zonguldak.
# Processing Record 1 of Set 1 | trairi.
# Processing Record 1 of Set 1 | estelle.
# Processing Record 1 of Set 1 | kiruna.
# Processing Record 1 of Set 1 | sokoni.
# City not found, skipping...
# Processing Record 1 of Set 1 | dingtao.
# Processing Record 1 of Set 1 | rauma.
# Processing Record 1 of Set 1 | mecca.
# Processing Record 1 of Set 1 | atasu.
# Processing Record 1 of Set 1 | kahului.
# Processing Record 1 of Set 1 | ahipara.
# Processing Record 1 of Set 1 | khasan.
# Processing Record 1 of Set 1 | sonoita.
# Processing Record 1 of Set 1 | zhangjiakou.
# Processing Record 1 of Set 1 | taoudenni.
# Processing Record 1 of Set 1 | nouadhibou.
# Processing Record 1 of Set 1 | kasangulu.
# City not found, skipping...
# Processing Record 1 of Set 1 | dingle.
# Processing Record 1 of Set 1 | fugen.
# Processing Record 1 of Set 1 | vuktyl.
# Processing Record 1 of Set 1 | pangnirtung.
# Processing Record 1 of Set 1 | pitiquito.
# Processing Record 1 of Set 1 | tessalit.
# Processing Record 1 of Set 1 | saurimo.
# Processing Record 1 of Set 1 | grand gaube.
# Processing Record 1 of Set 1 | yar-sale.
# Processing Record 1 of Set 1 | peleduy.
# Processing Record 1 of Set 1 | songjianghe.
# Processing Record 1 of Set 1 | mandalgovi.
# Processing Record 1 of Set 1 | sabang.
# Processing Record 1 of Set 1 | binzhou.
# City not found, skipping...
# City not found, skipping...
# Processing Record 1 of Set 1 | pampas.
# City not found, skipping...
# Processing Record 1 of Set 1 | chimore.
# Processing Record 1 of Set 1 | osmena.
# City not found, skipping...
# Processing Record 1 of Set 1 | mollendo.
# Processing Record 1 of Set 1 | maragogi.
# Processing Record 1 of Set 1 | dir.
# Processing Record 1 of Set 1 | trinidad.
# Processing Record 1 of Set 1 | calama.
# Processing Record 1 of Set 1 | loukhi.
# Processing Record 1 of Set 1 | nanae.
# Processing Record 1 of Set 1 | karaton.
# City not found, skipping...
# Processing Record 1 of Set 1 | qaqortoq.
# City not found, skipping...
# Processing Record 1 of Set 1 | manokwari.
# Processing Record 1 of Set 1 | aripuana.
# Processing Record 1 of Set 1 | tilichiki.
# City not found, skipping...
# Processing Record 1 of Set 1 | galesong.
# Processing Record 1 of Set 1 | belyy yar.
# City not found, skipping...
# Processing Record 1 of Set 1 | laguna.
# Processing Record 1 of Set 1 | york.
# Processing Record 1 of Set 1 | dongsheng.
# Processing Record 1 of Set 1 | luderitz.
# City not found, skipping...
# Processing Record 1 of Set 1 | guayata.
# Processing Record 1 of Set 1 | pocao de pedras.
# Processing Record 1 of Set 1 | den helder.
# Processing Record 1 of Set 1 | ipilan.
# Processing Record 1 of Set 1 | san andres.
# Processing Record 1 of Set 1 | port hedland.
# Processing Record 1 of Set 1 | kununurra.
# Processing Record 1 of Set 1 | kidal.
# Processing Record 1 of Set 1 | verkhniye tatyshly.
# Processing Record 1 of Set 1 | longyan.
# Processing Record 1 of Set 1 | verkhnevilyuysk.
# Processing Record 1 of Set 1 | tevaitoa.
# Processing Record 1 of Set 1 | anito.
# Processing Record 1 of Set 1 | banda aceh.
# Processing Record 1 of Set 1 | shimoda.
# Processing Record 1 of Set 1 | campbellsville.
# Processing Record 1 of Set 1 | sinegorskiy.
# Processing Record 1 of Set 1 | yeppoon.
# Processing Record 1 of Set 1 | pedasi.
# Processing Record 1 of Set 1 | thamaga.
# Processing Record 1 of Set 1 | nishihara.
# Processing Record 1 of Set 1 | lazaro cardenas.
# Processing Record 1 of Set 1 | komoro.
# Processing Record 1 of Set 1 | ambon.
# Processing Record 1 of Set 1 | honningsvag.
# Processing Record 1 of Set 1 | jumla.
# Processing Record 1 of Set 1 | mackay.
# Processing Record 1 of Set 1 | qasigiannguit.
# City not found, skipping...
# Processing Record 1 of Set 1 | mitsamiouli.
# Processing Record 1 of Set 1 | petropavlovsk-kamchatskiy.
# Processing Record 1 of Set 1 | kyrylivka.
# Processing Record 1 of Set 1 | esna.
# Processing Record 1 of Set 1 | ust-kuyga.
# City not found, skipping...
# Processing Record 1 of Set 1 | margate.
# Processing Record 1 of Set 1 | nelson bay.
# Processing Record 1 of Set 1 | erzurum.
# Processing Record 1 of Set 1 | tacoronte.
# Processing Record 1 of Set 1 | nakamura.
# Processing Record 1 of Set 1 | gilbues.
# Processing Record 1 of Set 1 | varzea grande.
# Processing Record 1 of Set 1 | ranot.
# Processing Record 1 of Set 1 | brigantine.
# Processing Record 1 of Set 1 | surin.
# Processing Record 1 of Set 1 | alofi.
# Processing Record 1 of Set 1 | sabya.
# Processing Record 1 of Set 1 | zhigansk.
# Processing Record 1 of Set 1 | los llanos de aridane.
# Processing Record 1 of Set 1 | gizo.
# Processing Record 1 of Set 1 | norman wells.
# Processing Record 1 of Set 1 | zdvinsk.
# Processing Record 1 of Set 1 | lima.
# Processing Record 1 of Set 1 | manado.
# Processing Record 1 of Set 1 | baiyin.
# Processing Record 1 of Set 1 | pleasanton.
# Processing Record 1 of Set 1 | magadi.
# Processing Record 1 of Set 1 | acapulco.
# Processing Record 1 of Set 1 | leningradskiy.
# Processing Record 1 of Set 1 | baiao.
# Processing Record 1 of Set 1 | torbay.
# Processing Record 1 of Set 1 | hambantota.
# Processing Record 1 of Set 1 | maketu.
# Processing Record 1 of Set 1 | nichinan.
# Processing Record 1 of Set 1 | hangu.
# Processing Record 1 of Set 1 | saint-georges.
# Processing Record 1 of Set 1 | the valley.
# Processing Record 1 of Set 1 | salalah.
# Processing Record 1 of Set 1 | coahuayana.
# Processing Record 1 of Set 1 | saraza.
# Processing Record 1 of Set 1 | waingapu.
# Processing Record 1 of Set 1 | lusaka.
# Processing Record 1 of Set 1 | saint-pierre.
# Processing Record 1 of Set 1 | marystown.
# City not found, skipping...
# Processing Record 1 of Set 1 | akhtubinsk.
# Processing Record 1 of Set 1 | cockburn town.
# Processing Record 1 of Set 1 | rosignol.
# Processing Record 1 of Set 1 | bandarbeyla.
# Processing Record 1 of Set 1 | tuatapere.
# Processing Record 1 of Set 1 | amarpur.
# Processing Record 1 of Set 1 | erenhot.
# City not found, skipping...
# Processing Record 1 of Set 1 | sanchazi.
# Processing Record 1 of Set 1 | seymchan.
# Processing Record 1 of Set 1 | adrar.
# Processing Record 1 of Set 1 | boyolangu.
# Processing Record 1 of Set 1 | komsomolskiy.
# Processing Record 1 of Set 1 | kopervik.
# Processing Record 1 of Set 1 | cauquenes.
# Processing Record 1 of Set 1 | dakoro.
# Processing Record 1 of Set 1 | babati.
# Processing Record 1 of Set 1 | marawi.
# Processing Record 1 of Set 1 | slave lake.
# Processing Record 1 of Set 1 | tupik.
# Processing Record 1 of Set 1 | muros.
# Processing Record 1 of Set 1 | fukue.
# Processing Record 1 of Set 1 | amapa.
# Processing Record 1 of Set 1 | naze.
# Processing Record 1 of Set 1 | talnakh.
# City not found, skipping...
# Processing Record 1 of Set 1 | mulege.
# Processing Record 1 of Set 1 | pathri.
# Processing Record 1 of Set 1 | yuanping.
# Processing Record 1 of Set 1 | taiping.
# Processing Record 1 of Set 1 | hirara.
# Processing Record 1 of Set 1 | yuzhno-kurilsk.
# Processing Record 1 of Set 1 | eydhafushi.
# City not found, skipping...
# City not found, skipping...
# Processing Record 1 of Set 1 | calabozo.
# Processing Record 1 of Set 1 | marienburg.
# Processing Record 1 of Set 1 | demidov.
# Processing Record 1 of Set 1 | bagotville.
# City not found, skipping...
# Processing Record 1 of Set 1 | waipawa.
# Processing Record 1 of Set 1 | aleksandrov gay.
# Processing Record 1 of Set 1 | vanavara.
# Processing Record 1 of Set 1 | yasnyy.
# Processing Record 1 of Set 1 | camacha.
# Processing Record 1 of Set 1 | morros.
# Processing Record 1 of Set 1 | north myrtle beach.
# Processing Record 1 of Set 1 | kumluca.
# Processing Record 1 of Set 1 | lunenburg.
# Processing Record 1 of Set 1 | puerto narino.
# Processing Record 1 of Set 1 | drummondville.
# Processing Record 1 of Set 1 | nabire.
# Processing Record 1 of Set 1 | acurenam.
# Processing Record 1 of Set 1 | ostrovnoy.
# Processing Record 1 of Set 1 | ukiah.
# Processing Record 1 of Set 1 | arman.
# Processing Record 1 of Set 1 | lesnoy gorodok.
# Processing Record 1 of Set 1 | quartucciu.
# Processing Record 1 of Set 1 | broken hill.
# Processing Record 1 of Set 1 | eyl.
# Processing Record 1 of Set 1 | samastipur.
# Processing Record 1 of Set 1 | honiara.
# Processing Record 1 of Set 1 | samarai.
# Processing Record 1 of Set 1 | hauterive.
# City not found, skipping...
# Processing Record 1 of Set 1 | iskateley.
# Processing Record 1 of Set 1 | labuhan.
# Processing Record 1 of Set 1 | usinsk.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": citynew,
    "Cloudiness": cloud,
    "Country": country,
    "Date" : date,
    "Humidity" : humidity,
    "Lat": lat,
    "Lon" : lon,
    "Max Temp" : maxtemp,
    "Wind Speed" :windspeed 
    
}

weather_data = pd.DataFrame(weather_dict)

weather_data.head()

weather_data.to_csv("weatherfile.csv")

# %%
weather_data.count()
# Out:
# City          540
# Cloudiness    540
# Country       540
# Date          540
# Humidity      540
# Lat           540
# Lon           540
# Max Temp      540
# Wind Speed    540
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o")

# Incorporate the other graph properties

current_time = datetime.now()

current_date = current_time.strftime('%m/%d/%Y')

plt.title(f"City Latitude vs. Max Temperature ({current_date})")

plt.ylabel("Max Temperature (Fahrenheit)")

plt.xlabel("Latitude")

plt.grid(True)

# Save the figure

plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o")

# Incorporate the other graph properties
current_time = datetime.now()

current_date = current_time.strftime('%m/%d/%Y')

plt.title(f"City Latitude vs. Humidity ({current_date})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o")

# Incorporate the other graph properties

current_time = datetime.now()

current_date = current_time.strftime('%m/%d/%Y')

plt.title(f"City Latitude vs. Cloudiness ({current_date})")


plt.title("Cloudiness in World Cities")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o")

# Incorporate the other graph properties


current_time = datetime.now()

current_date = current_time.strftime('%m/%d/%Y')

plt.title(f"City Latitude vs. Wind Speed ({current_date})")


plt.title("Wind Speed in World Cities")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Wind Speed.png")

# Show plot
plt.show()
